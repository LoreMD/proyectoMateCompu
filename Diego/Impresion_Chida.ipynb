# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
Am=np.matrix(((0, 1, 2, 0, 1,2),(0, 1, 2, 0, 1,2),(0, 1, 2, 0, 1,2),(0, 1, 2, 0, 1,2),(0, 1, 2, 0, 1,2)))
print Am
# Out:
# [[0 1 2 0 1 2]
#  [0 1 2 0 1 2]
#  [0 1 2 0 1 2]
#  [0 1 2 0 1 2]
#  [0 1 2 0 1 2]]

# %%
plt.imshow(Am)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
noise = np.random.random(((128,128)))
noise
# Out:
# array([[ 0.44204649,  0.85147709,  0.44444102, ...,  0.45763705,
#          0.39836256,  0.82244383],
#        [ 0.23775406,  0.75560603,  0.04488876, ...,  0.22116229,
#          0.03413208,  0.2714357 ],
#        [ 0.05630392,  0.51353158,  0.68205526, ...,  0.84601731,
#          0.79012356,  0.75004028],
#        ...,
#        [ 0.70261055,  0.01164217,  0.50312639, ...,  0.76921993,
#          0.52032983,  0.44103883],
#        [ 0.73653827,  0.34042199,  0.90763006, ...,  0.65010084,
#          0.03466768,  0.44574783],
#        [ 0.57031091,  0.50379928,  0.94422442, ...,  0.26430808,
#          0.64148513,  0.43471813]])

# %%
plt.imshow(noise)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import numpy as np

# %%
def matriz(n):
    bosque = np.matrix(np.ones((n,n)))
    aux = np.matrix(np.zeros((n,n)))

# %%
def fuego(f,p,loops,n):
    bosque = np.matrix(np.ones((n,n)))
    aux = np.matrix(np.zeros((n,n)))
    contador = 0
    random1 = 0.01*(random.randint(0,100))
    random2 = 0.01*(random.randint(0,100))
    
    for k in range(0,loops):
        for i in xrange(0,n-1):
            for j in xrange(0,n-1):
                if i==0:
                     if j==0:  #(0,0) 
                        if bosque[i,j] == 1:
                            if (vecindad...==2):
                                aux[i,j]==2
                                
                            if random1<=f:
                                aux[i,j]==2
                            
                            else:
                                aux[i,j]==1
                        
                        if bosque[i,j] == 2:
                            aux[i,j]==0
                        
                        else: #El arbol es 0
                            if random2<=p:
                                aux[i,j]==1
                            else:
                                aux[i,j]==0
                            
                    if j==n: #(0,n)
                        if bosque[i,j] == 1:
                            if (vecindad...==2):
                                aux[i,j]==2
                                
                            if random1<=f:
                                aux[i,j]==2
                            
                            else:
                                aux[i,j]==1
                        
                        if bosque[i,j] == 2:
                            aux[i,j]==0
                        
                        else: #El arbol es 0
                            if random2<=p:
                                aux[i,j]==1
                            else:
                                aux[i,j]==0
                            
                    else: #Primer renglón
                        if bosque[i,j] == 1:
                            if (vecindad...==2):
                                aux[i,j]==2
                                
                            if random1<=f:
                                aux[i,j]==2
                            
                            else:
                                aux[i,j]==1
                        
                        if bosque[i,j] == 2:
                            aux[i,j]==0
                        
                        else: #El arbol es 0
                            if random2<=p:
                                aux[i,j]==1
                            else:
                                aux[i,j]==0
                else:
                    if i==n:
                        if j==0: #(n,0)
                            if bosque[i,j] == 1:
                                if (vecindad...==2):
                                    aux[i,j]==2
                                
                                if random1<=f:
                                    aux[i,j]==2
                            
                                else:
                                    aux[i,j]==1
                        
                            if bosque[i,j] == 2:
                                aux[i,j]==0
                        
                            else: #El arbol es 0
                                if random2<=p:
                                    aux[i,j]==1
                                else:
                                    aux[i,j]==0
                            
                        else:
                            if j==n: #(n,n)
                                if bosque[i,j] == 1:
                                    if (vecindad...==2):
                                        aux[i,j]==2
                                
                                    if random1<=f:
                                        aux[i,j]==2
                            
                                    else:
                                        aux[i,j]==1
                        
                                if bosque[i,j] == 2:
                                    aux[i,j]==0
                        
                                else: #El arbol es 0
                                    if random2<=p:
                                        aux[i,j]==1
                                    else:
                                        aux[i,j]==0
                                        
                            else: #Último renglón
                                if bosque[i,j] == 1:
                                    if (vecindad...==2):
                                        aux[i,j]==2
                                
                                    if random1<=f:
                                        aux[i,j]==2
                            
                                    else:
                                        aux[i,j]==1
                        
                                if bosque[i,j] == 2:
                                    aux[i,j]==0
                        
                                else: #El arbol es 0
                                    if random2<=p:
                                        aux[i,j]==1
                                    else:
                                        aux[i,j]==0
                    else:
                        if j==0: #Primer columna
                            if bosque[i,j] == 1:
                                if (vecindad...==2):
                                    aux[i,j]==2
                                
                                if random1<=f:
                                    aux[i,j]==2
                            
                                else:
                                    aux[i,j]==1
                        
                            if bosque[i,j] == 2:
                                aux[i,j]==0
                        
                            else: #El arbol es 0
                                if random2<=p:
                                    aux[i,j]==1
                                else:
                                    aux[i,j]==0
                        else:
                            if j==n: #Última columna
                                if bosque[i,j] == 1:
                                    if (vecindad...==2):
                                        aux[i,j]==2
                                
                                    if random1<=f:
                                        aux[i,j]==2
                            
                                    else:
                                        aux[i,j]==1
                        
                                if bosque[i,j] == 2:
                                    aux[i,j]==0
                        
                                else: #El arbol es 0
                                    if random2<=p:
                                        aux[i,j]==1
                                    else:
                                        aux[i,j]==0
                                    
                            else: #Todo el interior de la matriz
                                if bosque[i,j] == 1:
                                    if (vecindad...==2):
                                        aux[i,j]==2
                                
                                    if random1<=f:
                                        aux[i,j]==2
                            
                                    else:
                                        aux[i,j]==1
                        
                                if bosque[i,j] == 2:
                                    aux[i,j]==0
                        
                                else: #El arbol es 0
                                    if random2<=p:
                                        aux[i,j]==1
                                    else:
                                        aux[i,j]==0
        
                                
        print bosque
        contador +=1
        print contador
        bosque = aux
    return bosque
# Out:
#   File "<ipython-input-4-1a3550a6b40b>", line 15
#     if (vecindad...==2):
#                  ^
# SyntaxError: invalid syntax

# %%
fuego(0.1,0.3,5,4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-86d82e612098> in <module>()
# ----> 1 fuego(0.1,0.3,5,4)
#
# NameError: name 'fuego' is not defined

# %% [markdown]
# #

# %%
import random

# %%
p=0.01*(random.randint(0,100))
x
# Out:
# 0.76

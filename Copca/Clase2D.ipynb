# %%
import numpy as np
from random import randint

# %%
class AutomataCelular2D: #de aqui van a heredar arena y bosque
    
    def __init__ (self, L):
        """
        L es el lado del cuadrado
        """
        self.L=L
        self.array=self.startRandom()
        self.next = 0
         
    """
    codigo siguiente copiado de lo de clase, y modificado para 2 dimensiones
    """
    #falta modificar
    def startSingle(self):
        """solo un granito de arena/fuego a la mitad del arreglo"""
        self.array[self.L/2, self.L/2] = 1
        self.next += 1

    def startRandom(self):
        """Valores aleatorios en el tiempo t_0"""
        array=np.zeros([self.L, self.L])
        for i in xrange(0,self.L,1):
            for j in xrange(0, self.L,1):
                array[i,j]=randint(1,10)
        return array
        
    def loop(self, steps=1):
        """Ejecuta el número especificado de pasos."""
        [self.step() for i in xrange(steps)]

    def step(self):
        """Avanza un paso t -> t+1."""
        pass

# %%
class montonArena(AutomataCelular2D):
    def __init__ (self, L):
        AutomataCelular2D.__init__(self, L)
        self.pendienteCritica=15
        self.next=0
    def dinamicaArena(self):
        aux=np.zeros((self.L, self.L))
        bandera=True
        j=1
        while (bandera==True ):
            for i in xrange(1, self.L-1):
                if j==self.L-1:
                    bandera=False
                else:
                    pendiente=self.array[i,j]+self.array[i,j+1]
                    pendiente+=self.array[i, j-1]
                    pendiente+=self.array[i+1, j]
                    pendiente+=self.array[i-1, j-1]
                    if pendiente>self.pendienteCritica:
                        bandera=False
                    """la bandera es para sacarte del while, porque tiene que checar que la pila completa sea estable/inestable"""
            j+=1
        if pendiente>self.pendienteCritica:
            for j in xrange(0, self.L, 1):
                for i in xrange(0,self.L-1,1):
                    aux[j,i]=self.array[j,i]-1
                    aux[j,i+1]=self.array[j,i+1]+1
                """
                se desparrama
                """
            self.array=aux
            print self.array
            self.dinamicaArena()
        else:
            """
            crece
            """
            print 'estable'
    def a(self):
        return self.array

# %%
prueba=montonArena(20)
prueba.a()
# Out:
# array([[  4.,  10.,   3.,   9.,   1.,   2.,   9.,   8.,  10.,   4.,   9.,
#           6.,   5.,   7.,   5.,   7.,   9.,   7.,  10.,   9.],
#        [  5.,   8.,   8.,   8.,   8.,  10.,   3.,   8.,  10.,   3.,   2.,
#           6.,   9.,  10.,   7.,   6.,   5.,   2.,   7.,   8.],
#        [  5.,   8.,   5.,   6.,   1.,   7.,   4.,   4.,   3.,   7.,   8.,
#          10.,   1.,   4.,   8.,   8.,   9.,   3.,   3.,   4.],
#        [ 10.,   2.,  10.,   7.,   8.,   2.,  10.,   3.,   7.,   3.,   7.,
#           6.,   7.,   5.,   3.,   1.,   2.,  10.,   7.,   2.],
#        [  6.,   2.,   5.,   8.,   7.,   3.,   2.,   4.,   5.,   2.,   1.,
#           7.,   3.,   8.,  10.,   8.,   9.,   7.,   9.,   4.],
#        [  1.,   9.,  10.,   3.,   8.,  10.,   5.,   7.,   7.,   7.,   2.,
#           3.,   5.,   6.,   4.,   1.,   4.,   4.,   3.,   1.],
#        [  9.,   8.,   7.,   4.,   8.,   3.,   8.,   6.,   5.,   1.,   6.,
#           2.,   6.,   7.,   9.,   5.,  10.,   7.,   8.,   4.],
#        [  3.,  10.,   8.,   2.,   9.,   4.,   1.,   3.,   5.,   3.,   7.,
#           5.,   2.,   7.,   1.,   5.,   4.,   3.,   5.,   9.],
#        [  6.,   8.,   6.,   4.,  10.,   4.,   1.,   8.,   3.,   1.,   8.,
#           9.,   8.,   5.,   8.,  10.,   3.,   5.,   4.,   9.],
